# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv("/var/home/rafo/vscode02/time.recipt.data/GDPUS.csv",parse_dates=["Year"])

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    63 non-null     datetime64[ns]
#  1   GDP     63 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.1 KB

# %%
df
# Out:
#          Year     GDP
# 0  1929-01-01   821.8
# 1  1930-01-01   748.9
# 2  1931-01-01   691.3
# 3  1932-01-01   599.7
# 4  1933-01-01   587.1
# ..        ...     ...
# 58 1987-01-01  4718.6
# 59 1988-01-01  4784.6
# 60 1989-01-01  4739.2
# 61 1990-01-01  4822.3
# 62 1991-01-01  4835.0
#
# [63 rows x 2 columns]

# %%
data_range = pd.date_range(start="1910-10-10",end ="1990-10-11",freq = "A" )

# %%
df["TimeIndex"] = pd.DataFrame(data_range,columns=["Year"])

# %%
df
# Out:
#          Year     GDP  TimeIndex
# 0  1929-01-01   821.8 1910-12-31
# 1  1930-01-01   748.9 1911-12-31
# 2  1931-01-01   691.3 1912-12-31
# 3  1932-01-01   599.7 1913-12-31
# 4  1933-01-01   587.1 1914-12-31
# ..        ...     ...        ...
# 58 1987-01-01  4718.6 1968-12-31
# 59 1988-01-01  4784.6 1969-12-31
# 60 1989-01-01  4739.2 1970-12-31
# 61 1990-01-01  4822.3 1971-12-31
# 62 1991-01-01  4835.0 1972-12-31
#
# [63 rows x 3 columns]

# %%
ax = plt.plot(df["Year"],df["GDP"])
plt.legend(loc = "best")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df["moving_avarage"] = df["GDP"].rolling(5).mean()

# %% [markdown]
# MA forcast

# %%
plt.plot(df["Year"],df["moving_avarage"],color = "purple",label = "GDP moveing avarage per year")
plt.plot(df["Year"],df["GDP"],color = "green",label = "GDP per year")
plt.grid(True)
plt.xlabel("Year")
plt.ylabel("GDP and GDP avarage")
plt.legend(loc = "upper left")
plt.show()
