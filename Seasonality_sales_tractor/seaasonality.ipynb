# %%
import pandas as pd
import matplotlib.pyplot as plt
sales_data =pd.read_csv("/var/home/rafo/vscode02/Seasonality/tractor_salesSales.csv")

# %%
sales_data.head(4)
# Out:
#   Month-Year  Number of Tractor Sold
# 0      3-Jan                     141
# 1      3-Feb                     157
# 2      3-Mar                     185
# 3      3-Apr                     199

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Month-Year              144 non-null    object
#  1   Number of Tractor Sold  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
sales_data
# Out:
#      Month-Year  Number of Tractor Sold
# 0    03.01.1900                     141
# 1    03.02.1900                     157
# 2    03.03.1900                     185
# 3    03.04.1900                     199
# 4    03.05.1900                     203
# ..          ...                     ...
# 139  14.08.1900                     848
# 140  14.09.1900                     640
# 141  14.10.1900                     581
# 142  14.11.1900                     519
# 143  14.12.1900                     605
#
# [144 rows x 2 columns]

# %%
sales_data["Month-Year"] = pd.to_datetime(sales_data["Month-Year"],format ="%d.%m.%Y")

# %%
sales_data["Month-Year"]=pd.to_datetime(sales_data["Month-Year"])+ pd.Timedelta(days= 365*80)

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Month-Year              144 non-null    datetime64[ns]
#  1   Number of Tractor Sold  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
sales_data
# Out:
#     Month-Year  Number of Tractor Sold
# 0   2022-12-04                     141
# 1   2023-01-04                     157
# 2   2023-02-01                     185
# 3   2023-03-04                     199
# 4   2023-04-03                     203
# ..         ...                     ...
# 139 2023-07-15                     848
# 140 2023-08-15                     640
# 141 2023-09-14                     581
# 142 2023-10-15                     519
# 143 2023-11-14                     605
#
# [144 rows x 2 columns]

# %%
sales_data["Month-Year"] = pd.to_datetime(sales_data["Month-Year"],format ="%d.%m.%Y",dayfirst= True)

# %%
sales_data
# Out:
#     Month-Year  Number of Tractor Sold
# 0   2022-12-04                     141
# 1   2023-01-04                     157
# 2   2023-02-01                     185
# 3   2023-03-04                     199
# 4   2023-04-03                     203
# ..         ...                     ...
# 139 2023-07-15                     848
# 140 2023-08-15                     640
# 141 2023-09-14                     581
# 142 2023-10-15                     519
# 143 2023-11-14                     605
#
# [144 rows x 2 columns]

# %%
date_range = pd.date_range(start= "2022-12-01",freq = "MS",periods=len(sales_data["Number of Tractor Sold"]))

# %%
import matplotlib.pyplot as plt 
fig = plt.gca()
fig.plot(sales_data["Month-Year"],sales_data["Number of Tractor Sold"])

# %%
fig02 = plt.gca()
fig02.plot(date_range,sales_data["Number of Tractor Sold"])
