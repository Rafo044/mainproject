# %%
import pandas as pd
df = pd.read_csv("/var/home/rafo/vscode02/time.recipt.data/daily-minimum-temperatures.csv", usecols= [0,1])

# %%
df
# Out:
#             Date Daily minimum temperatures in Melbourne, Australia, 1981-1990
# 0     1981-01-01                                               20.7
# 1     1981-01-02                                               17.9
# 2     1981-01-03                                               18.8
# 3     1981-01-04                                               14.6
# 4     1981-01-05                                               15.8
# ...          ...                                                ...
# 3647  1990-12-29                                               13.5
# 3648  1990-12-30                                               15.7
# 3649  1990-12-31                                               13.0
# 3650         NaN                                                NaN
# 3651         NaN                                                NaN
#
# [3652 rows x 2 columns]

# %%
df["Date"]= pd.to_datetime(df["Date"],format = "%Y-%m-%d")

# %%
df
# Out:
#            Date Daily minimum temperatures in Melbourne, Australia, 1981-1990
# 0    1981-01-01                                               20.7
# 1    1981-01-02                                               17.9
# 2    1981-01-03                                               18.8
# 3    1981-01-04                                               14.6
# 4    1981-01-05                                               15.8
# ...         ...                                                ...
# 3647 1990-12-29                                               13.5
# 3648 1990-12-30                                               15.7
# 3649 1990-12-31                                               13.0
# 3650        NaT                                                NaN
# 3651        NaT                                                NaN
#
# [3652 rows x 2 columns]

# %%
df.dropna(inplace= True)

# %%
import matplotlib.pyplot as plt
df.plot()
# Out:
# <Axes: >

# %%
import plotly_express as px
fig = px.line(df,y = "Daily minimum temperatures in Melbourne, Australia, 1981-1990", x = "Date")
fig.show()

# %% [markdown]
# Plot a box plot by month
